# %%
# %fs ls

# %%
# %fs ls 'abfss://demo-container-01@deacourseextdeltatable.dfs.core.windows.net/'

# %%
# %sql
create external location if not exists dea_course_ext_dl_demo
url 'abfss://demo-container-01@deacourseextdeltatable.dfs.core.windows.net/'
with (storage credential `dea-course-ext-sc`)
comment 'External Location for Demo'

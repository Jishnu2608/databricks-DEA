# %% [markdown]
# ## Data Magic Commands

# %% [markdown]
# - %python, %scala, &r, %sql : Switch to different language for a specific cell
# - %md - Markdown
# - %fs - Run file system commands
# - %pip - Install Python libraries when cluster starts
# - %run - Include / import another notebook into the current notebook
# - %sh - Run shell commands (Driver Node only)

# %%
# %fs 
ls /databricks-datasets/

# %%
# %sh 
ps

# %%
# %pip install faker

# %%
# %run "./Env Variables - Magic Commands"

# %%
env

# %%
print_env_info()

# %%
env = 'dev'

# %%
import os
import platform

def print_env_info():
    print(f"Python Version : {platform.python_version()}")
    print(f"Spark Version : {spark.version}")
    print(f"Running on Databricks : {os.environ.get('DATABRICKS_RUNTIME_VERSION', 'Unknown')}")

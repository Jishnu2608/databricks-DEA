-- %% [markdown]
-- # Setup project environment for Gizmobox Data Lakehouse

-- %%
%fs ls 'abfss://gizmo-box@deacourseextdeltatable.dfs.core.windows.net/landing'

-- %%
%sql
create external location if not exists dea_course_ext_dl_gizmobox
url 'abfss://gizmo-box@deacourseextdeltatable.dfs.core.windows.net/'
with (storage credential `dea-course-ext-sc`)
comment 'External Location or GizmoBox Data lakehouse'

-- %%
show catalogs;

-- %%
create catalog if not exists gizmobox
managed location 'abfss://gizmo-box@deacourseextdeltatable.dfs.core.windows.net/'
comment 'This is the catalog for the Gizmobox Data Lakehouse'

-- %% [markdown]
-- ### Create schemas
-- 1. Landing
-- 2. Bronze
-- 3. Silver
-- 4. Gold

-- %%
use catalog gizmobox;

create schema if not exists landing
managed location 'abfss://gizmo-box@deacourseextdeltatable.dfs.core.windows.net/landing';
create schema if not exists bronze
managed location 'abfss://gizmo-box@deacourseextdeltatable.dfs.core.windows.net/bronze';
create schema if not exists silver
managed location 'abfss://gizmo-box@deacourseextdeltatable.dfs.core.windows.net/silver';
create schema if not exists gold
managed location 'abfss://gizmo-box@deacourseextdeltatable.dfs.core.windows.net/gold';

-- %%
use catalog gizmobox;
use schema landing;

create external volume if not exists operational_data
location 'abfss://gizmo-box@deacourseextdeltatable.dfs.core.windows.net/landing/operational_data/'

-- %%
%fs ls /Volumes/gizmobox/landing/operational_data

-- %%
%python 

customer_df = spark.sql('select * from json.`/Volumes/gizmobox/landing/operational_data/customers`')
display(customer_df)

-- %% [markdown]
-- ## Spark DataFrameReader API

-- %%
%python 
customer_df_2 = spark.read.format('json').load('/Volumes/gizmobox/landing/operational_data/customers')
display(customer_df_2)

-- %% [markdown]
-- ## spark.table function

-- %%
%python

address_df = spark.table('gizmobox.bronze.v_addresses')
display(address_df)

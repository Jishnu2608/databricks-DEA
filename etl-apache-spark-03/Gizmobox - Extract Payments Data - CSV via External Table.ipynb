-- %%
%fs ls 'abfss://gizmo-box@deacourseextdeltatable.dfs.core.windows.net/landing/external_data/payments'

-- %% [markdown]
-- ## Create External Table

-- %%
create table if not exists gizmobox.bronze.payments
(payment_id integer, order_id integer, payment_timestamp timestamp, 
payment_status integer, payment_method string)
using csv
options (
  header = 'true',
  delimiter = ','
)
location 'abfss://gizmo-box@deacourseextdeltatable.dfs.core.windows.net/landing/external_data/payments'

-- %%
select * from gizmobox.bronze.payments;

-- %%
describe extended gizmobox.bronze.payments;

-- refresh table refreshes the table metadata if any file deletes in the azure portal

-- %%
select p.*, r.* from 
gizmobox.bronze.payments p
inner join asql_gizmobox_db_catalog_ui.dbo.refunds r 
on r.payment_id = p.payment_id
